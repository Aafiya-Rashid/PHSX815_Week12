# %%
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(42)
data = np.random.normal(loc=0, scale=1, size=1000)


x = np.linspace(-5, 5, num=1000)


h = 0.5


kde = KernelDensity(kernel='gaussian', bandwidth=h).fit(data[:, np.newaxis])
log_dens = kde.score_samples(x[:, np.newaxis])
dens = np.exp(log_dens)

fig, ax = plt.subplots()
ax.hist(data, bins=30, density=True, alpha=0.5)
ax.plot(x, dens, lw=3, label='KDE estimate')
ax.set_xlabel('Data')
ax.set_ylabel('Density')
ax.legend(loc='best')
plt.savefig('HW_13')
plt.show()
